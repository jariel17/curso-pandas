# %%
import pandas as pd
import os

# %%
if '__file__' in globals():
    current_dir = os.path.dirname(__file__)
else:
    current_dir = os.getcwd()

# %%
bestsellers = os.path.join(current_dir, "datasets", "bestsellers.csv")
games = os.path.join(current_dir, "datasets", "games.csv")
pokemon= os.path.join(current_dir, "datasets", "Pokemon_full.csv")

# %%
df_books = pd.read_csv(bestsellers)
df_games = pd.read_csv(games)
df_pokemon = pd.read_csv(pokemon)

# %%
df_books.groupby('Author').count()
# Out:
#                             Name  User Rating  Reviews  Price  Year  Genre
# Author
# Abraham Verghese               2            2        2      2     2      2
# Adam Gasiewski                 1            1        1      1     1      1
# Adam Mansbach                  1            1        1      1     1      1
# Adir Levy                      1            1        1      1     1      1
# Admiral William H. McRaven     1            1        1      1     1      1
# ...                          ...          ...      ...    ...   ...    ...
# Walter Isaacson                3            3        3      3     3      3
# William Davis                  2            2        2      2     2      2
# William P. Young               2            2        2      2     2      2
# Wizards RPG Team               3            3        3      3     3      3
# Zhi Gang Sha                   2            2        2      2     2      2
#
# [248 rows x 6 columns]

# %%
df_books.groupby('Author').sum().loc['Walter Isaacson']
# Out:
# Name           Leonardo da VinciSteve JobsSteve Jobs
# User Rating                                     13.7
# Reviews                                        18668
# Price                                             61
# Year                                            6040
# Genre              Non FictionNon FictionNon Fiction
# Name: Walter Isaacson, dtype: object

# %%
df_books.groupby('Author').sum().reset_index()
# Out:
#                          Author
# 0              Abraham Verghese  \
# 1                Adam Gasiewski
# 2                 Adam Mansbach
# 3                     Adir Levy
# 4    Admiral William H. McRaven
# ..                          ...
# 243             Walter Isaacson
# 244               William Davis
# 245            William P. Young
# 246            Wizards RPG Team
# 247                Zhi Gang Sha
#
#                                                   Name  User Rating  Reviews
# 0                   Cutting for StoneCutting for Stone          9.2     9732  \
# 1    Milk and Vine: Inspirational Quotes From Class...          4.4     3113
# 2                                 Go the F**k to Sleep          4.8     9568
# 3    What Should Danny Do? (The Power to Choose Ser...          4.8     8170
# 4    Make Your Bed: Little Things That Can Change Y...          4.7    10199
# ..                                                 ...          ...      ...
# ...

# %%
df_books.groupby('Author').agg({'Price': ['min', 'max', 'mean']})
# Out:
#                            Price
#                              min max       mean
# Author
# Abraham Verghese              11  11  11.000000
# Adam Gasiewski                 6   6   6.000000
# Adam Mansbach                  9   9   9.000000
# Adir Levy                     13  13  13.000000
# Admiral William H. McRaven    11  11  11.000000
# ...                          ...  ..        ...
# Walter Isaacson               20  21  20.333333
# William Davis                  6   6   6.000000
# William P. Young               8   8   8.000000
# Wizards RPG Team              27  27  27.000000
# Zhi Gang Sha                   6  17  11.500000
#
# [248 rows x 3 columns]

# %%
df_pokemon.head(2)
# Out:
#         name  pokedex id  height  weight   type secundary type  hp  attack
# 0  bulbasaur           1       7      69  grass         poison  45      49  \
# 1    ivysaur           2      10     130  grass         poison  60      62
#
#    defense  sp atk  sp def  speed
# 0       49      65      65     45
# 1       63      80      80     60

# %%
df_pokemon.groupby('type').agg({'attack': ['min', 'max', 'mean'], 
                                'sp atk': ['min', 'max', 'mean'], 
                                'defense': ['min', 'max', 'mean'], 
                                'sp def': ['min', 'max', 'mean'], 
                                'speed': ['min', 'max', 'mean']}).sort_values(('speed', 'mean'), ascending=False)
# Out:
#          attack                 sp atk                 defense
#             min  max       mean    min  max       mean     min  max
# type
# electric     30  123  73.354167     35  173  83.958333      15  115  \
# flying       30  115  71.571429     33  125  68.714286      35  105
# dragon       50  150  98.766667     30  150  79.633333      30  125
# fire         40  140  83.741379     15  151  82.637931      37  140
# dark         28  131  83.342857     30  135  71.142857      28  115
# psychic      20  150  63.245614     23  154  91.333333      15  131
# poison       43  106  73.028571     30  145  66.142857      35  152
# normal        5  160  73.862385     15  135  56.045872       5  120
# fighting     35  140  99.352941     20  115  52.529412      30  115
# water        10  130  71.195122     10  150  71.211382      20  180
# bug          10  139  66.253333     10  145  56.720000      20  230
# ice          25  130  70.407407     30  130  77.259259      15  184
# ...

# %%
df_pokemon.groupby(['type', 'secundary type']).count().head(20)
# Out:
#                      name  pokedex id  height  weight  hp  attack  defense
# type secundary type
# bug  electric           4           4       4       4   4       4        4  \
#      fairy              2           2       2       2   2       2        2
#      fighting           3           3       3       3   3       3        3
#      fire               2           2       2       2   2       2        2
#      flying            13          13      13      13  13      13       13
#      ghost              1           1       1       1   1       1        1
#      grass              6           6       6       6   6       6        6
#      ground             1           1       1       1   1       1        1
#      poison            11          11      11      11  11      11       11
#      psychic            2           2       2       2   2       2        2
#      rock               3           3       3       3   3       3        3
# ...
